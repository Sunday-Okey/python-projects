# %% [markdown]
# ## Introduction to Python Objects

# %%
print("Hello World")

# %%
"""
aaaaa
bbbb'''cccc
pppp
"""

# %%
0b111

# %%
type(0b111)

# %%
dict(key=10)

# %%
dict(a = 2, b = 3, c = 5)

# %%
set('abcaaaaaaaabnm')
